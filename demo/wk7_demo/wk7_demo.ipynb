# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -r requirements.txt  # install

import utils
display = utils.notebook_init() # check
# Out:
# YOLOv5 🚀 v6.2-78-g5f1000a Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.4/78.2 GB disk)

# %%
import torch
from IPython.display import Image  # for displaying images

print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.12.1+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pCjhgO6AaDWtsuKCrLgf")
project = rf.workspace("utas").project("bccd-bmowf")
dataset = project.version(1).download("yolov5")

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/drive/MyDrive/datasets/yolo_test.zip /content/.

# %%
# !unzip /content/yolo_test.zip -d /content/yolo_test

# %%
# %cat /content/yolov5/data/data.yaml
# Out:
# train: /content/yolo_test/train/images
# val: /content/yolo_test/valid/images
#
# nc: 2
# names: ['husky', 'shepherd']

# %%
# !python train.py --img 640 --batch 2 --epochs 50 --data data.yaml --weights yolov5s.pt --cache

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --conf 0.05 --source /content/yolo_test/test/images/
